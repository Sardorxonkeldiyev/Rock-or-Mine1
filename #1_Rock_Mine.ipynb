# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv('/content/Copy of sonar data.csv', header=None)
df.head()

# %%
df.shape

# %%
df.info()

# %%
df.describe()

# %%
df[60].value_counts()

# %%
X = df.drop(columns=[60], axis=1)
Y = df[60]
Y = Y.values.reshape(-1)  # Reshape Y into a 1D array

# %%
# Splitting the data into training and testing:
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.1, random_state=42)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)

# %%
# Model evaluation: (train)

train_predict = model.predict(X_train)
accuracy_train = accuracy_score(train_predict, y_train)
print('Accuracy score training: ', accuracy_train)

# %%
# Model evaluation : (test)

test_predict = model.predict(X_test)
accuracy_test = accuracy_score(test_predict, y_test)
print('Accuracy score test: ', accuracy_test)

# %% [markdown]
# # Making predictive system

# %%
in_data = (0.0286,0.0453,0.0277,0.0174,0.0384,0.0990,0.1201,0.1833,0.2105,0.3039,0.2988,0.4250,0.6343,0.8198,1.0000,0.9988,0.9508,0.9025,0.7234,0.5122,0.2074,0.3985,0.5890,0.2872,0.2043,0.5782,0.5389,0.3750,0.3411,0.5067,0.5580,0.4778,0.3299,0.2198,0.1407,0.2856,0.3807,0.4158,0.4054,0.3296,0.2707,0.2650,0.0723,0.1238,0.1192,0.1089,0.0623,0.0494,0.0264,0.0081,0.0104,0.0045,0.0014,0.0038,0.0013,0.0089,0.0057,0.0027,0.0051,0.0062)
in_data_np = np.asarray(in_data)

in_data_reshape = in_data_np.reshape(1, -1)
prediction = model.predict(in_data_reshape)
print(prediction)

if prediction[0] == 'R':
    print("The object is Rock")
else:
    print("The object is Mine")
